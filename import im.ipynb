# %%
import numpy as np
import matplotlib.pylab as plt

# %matplotlib inline

# %%
im = plt.imread('cat.jpeg')
im.shape
# Out:
# (495, 660, 3)

# %%
plt.imshow(im)

# %%
im[0,0]
# Out:
# array([191, 188, 195], dtype=uint8)

# %%
im[0,0][0]
# Out:
# 191

# %%
im[0,0][2]
# Out:
# 195

# %%
im.shape
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-afbdf33aed57> in <module>()
# ----> 1 im.shape
#
# NameError: name 'im' is not defined

# %%
plt.imshow(im)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a9282a591582> in <module>()
# ----> 1 plt.imshow(im)
#
# NameError: name 'plt' is not defined
